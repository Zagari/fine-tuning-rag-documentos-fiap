# %%
#Conexão com o Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import requests
from bs4 import BeautifulSoup
import json

def get_news_content(links_file):
    # Carrega o arquivo com os links e retorna uma lista
    with open(links_file, 'r') as file:
        links = set(file.readlines())
    news_contents = []

    for link in links:
        link = link.strip()  # Limpa a URL, se necessário
        print(link)
        response = requests.get(link)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')

            # Localiza o elemento que contém o conteúdo do artigo
            article_content = soup.find('div', class_='article__content')
            if article_content:
                print(article_content)
                paragraphs = article_content.find_all('p', class_='paragraph inline-placeholder')
                # Concatena o texto de todos os parágrafos encontrados
                content = ' '.join(p.get_text(strip=True) for p in paragraphs)
                news_contents.append(content)
                print(content)
            else:
                news_contents.append("Conteúdo não encontrado.")
        else:
            news_contents.append(f"Falha ao extrair o conteúdo da notícia: {response.status_code}")

    # Salva o conteúdo em um arquivo JSON
    with open('news_contents.json', 'w') as json_file:
        json.dump({"news_content": news_contents}, json_file)

# Chamada da função para extrair os conteúdos
get_news_content('drive/MyDrive/FIAP/CNN_Links.txt')
# Out:
# https://www.cnn.com/2026/02/19/middleeast/british-couple-jailed-espionage-iran-10-years-intl
#
# https://www.cnn.com/2026/02/20/style/method-dressing-red-carpet
#
# https://www.cnn.com/2026/02/19/world/timeline-andrew-arrest-jeffrey-epstein-intl
#
# https://www.cnn.com/2026/02/22/europe/ukraine-widows-demographic-crisis-intl
#
# https://www.cnn.com/2026/02/20/europe/trash-dumping-dog-trained-italy-intl-scli
#
# https://www.cnn.com/2026/02/21/sport/usa-mens-hockey-miracle-on-ice-inspiration
#
# https://www.cnn.com/2026/02/19/asia/south-korea-yoon-suk-yeol-verdict-insurrection-intl-hnk
#
# https://www.cnn.com/2026/02/21/sport/rondale-moore-dies-at-25-nfl
#
# https://www.cnn.com/2026/02/21/travel/travel-news-canada-underground-path-reso
#
# https://www.cnn.com/2026/02/22/europe/france-us-ambassador-quentin-deranque-death-intl
#
# https://www.cnn.com/2026/02/21/middleeast/huckabee-israel-us-land-intl
#
# https://www.cnn.com/2026/02/19/world/video/the-odds-what-the-arrest-of-former-prince-andrew-could-mean-for-uk-pm-starmer-cnc-kalpar
# https://www.cnn.com/2026/02/11/style/mandy-moore-home-altadena-ad
#
# https://www.cnn.com/2026/02/17/americas/peru-president-jose-jeri-ousted-intl-latam
#
# https://www.cnn.com/2026/02/05/world/gallery/photos-this-week-january-29-february-5
# https://www.cnn.com/2026/02/19/tech/apple-west-virginia-lawsuit-icloud
#
# https://www.cnn.com/2026/02/18/tech/meta-mark-zuckerberg-testifies-social-media-addiction-trial
#
# https://www.cnn.com/2026/02/21/europe/slovakia-ukraine-oil-energy-threat-intl
#
# https://www.cnn.com/2026/02/22/tech/social-media-addiction-trial-tobacco-moment
#
# https://www.cnn.com/2026/02/20/world/video/andrew-mountbatten-windsor-epstein-investigation-max-foster-pkg-latam-intl
# https://www.cnn.com/2026/02/21/europe/us-ambassadors-antagonism-europe-intl
